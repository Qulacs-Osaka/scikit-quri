# %%
from quri_parts.core.estimator.gradient import (
    create_numerical_gradient_estimator,
)
from quri_parts.qulacs.estimator import (
    create_qulacs_vector_concurrent_parametric_estimator,
)
from quri_parts.algo.optimizer import Adam, LBFGS

# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from quri_parts.circuit.utils.circuit_drawer import draw_circuit

iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
x = df.loc[:, ["petal length (cm)", "petal width (cm)"]]
x_train, x_test, y_train, y_test = train_test_split(x, iris.target, test_size=0.25, random_state=0)
x_train = x_train.to_numpy()

n_qubits = 5
num_class = 3

# %%
from scikit_quri.circuit import create_qcl_ansatz

circuit = create_qcl_ansatz(n_qubits, 3, 1.0)
draw_circuit(circuit.circuit)
circuit.circuit.parameter_count
# Out:
#    ___     ___     ___
#   |PRY|   |PRZ|   |RX |
# --|0  |---|1  |---|10 |-----●---------------●-------●-----------------------●---
#   |___|   |___|   |___|     |               |       |                       |
#    ___     ___             _|_     ___     _|_      |     ___               |
#   |PRY|   |PRZ|           |CX |   |RZ |   |CX |     |    |RX |              |
# --|2  |---|3  |-----------|11 |---|12 |---|13 |-----|----|23 |--------------|---
#   |___|   |___|           |___|   |___|   |___|     |    |___|              |
#    ___     ___                                     _|_             ___     _|_
#   |PRY|   |PRZ|                                   |CX |           |RZ |   |CX |
# --|4  |---|5  |-----------------------------------|14 |-----------|15 |---|16 |-
#   |___|   |___|                                   |___|           |___|   |___|
#    ___     ___
#   |PRY|   |PRZ|
# --|6  |---|7  |-----------------------------------------------------------------
#   |___|   |___|
#    ___     ___
#   |PRY|   |PRZ|
# --|8  |---|9  |-----------------------------------------------------------------
#   |___|   |___|
#
#
# ================================================================================
#
#
#
# ----●-----------------------●---------------●-------------------------------●---
#     |                       |               |                               |
#     |                       |               |                               |
#     |                       |               |                               |
# ----|------●----------------|------●--------|------●------------------------|---
#     |      |                |      |        |      |                        |
#     |     _|_      ___      |     _|_       |      |      ___               |
#     |    |CX |    |RZ |     |    |CX |      |      |     |RX |              |
# ----|----|24 |----|25 |-----|----|26 |------|------|-----|33 |--------------|---
#     |    |___|    |___|     |    |___|      |      |     |___|              |
#    _|_             ___     _|_              |     _|_              ___      |
#   |CX |           |RZ |   |CX |             |    |CX |            |RZ |     |
# --|17 |-----------|18 |---|19 |-------------|----|27 |------------|28 |-----|---
#   |___|           |___|   |___|             |    |___|            |___|     |
#                                            _|_                     ___     _|_
#                                           |CX |                   |RZ |   |CX |
# ------------------------------------------|20 |-------------------|21 |---|22 |-
#                                           |___|                   |___|   |___|
#
#
# ================================================================================
#
#            ___             ___     ___             ___
#           |PRX|           |PRZ|   |PRX|           |RX |
# ----------|45 |-----------|46 |---|47 |-----------|60 |-------------------------
#           |___|           |___|   |___|           |___|
#                                                    ___             ___     ___
#                                                   |PRX|           |PRZ|   |PRX|
# ---●--------●-----------------------●-------------|48 |-----------|49 |---|50 |-
#    |        |                       |             |___|           |___|   |___|
#    |        |                       |
#    |        |                       |
# ---|--------|------●----------------|------●--------●-----------------------●---
#    |        |      |                |      |        |                       |
#   _|_       |     _|_      ___      |     _|_       |     ___               |
#  |CX |      |    |CX |    |RZ |     |    |CX |      |    |RX |              |
# -|29 |------|----|34 |----|35 |-----|----|36 |------|----|40 |--------------|---
#  |___|      |    |___|    |___|     |    |___|      |    |___|              |
#            _|_             ___     _|_             _|_             ___     _|_
#           |CX |           |RZ |   |CX |           |CX |           |RZ |   |CX |
# ----------|30 |-----------|31 |---|32 |-----------|37 |-----------|38 |---|39 |-
#           |___|           |___|   |___|           |___|           |___|   |___|
#
#
# ================================================================================
#
#
#
# ----●---------------●-------●-----------------------●-------●-------------------
#     |               |       |                       |       |
#    _|_     ___     _|_      |     ___               |       |
#   |CX |   |RZ |   |CX |     |    |RX |              |       |
# --|61 |---|62 |---|63 |-----|----|73 |--------------|-------|------●------------
#   |___|   |___|   |___|     |    |___|              |       |      |
#    ___     ___     ___     _|_             ___     _|_      |     _|_      ___
#   |PRX|   |PRZ|   |PRX|   |CX |           |RZ |   |CX |     |    |CX |    |RZ |
# --|51 |---|52 |---|53 |---|64 |-----------|65 |---|66 |-----|----|74 |----|75 |-
#   |___|   |___|   |___|   |___|           |___|   |___|     |    |___|    |___|
#                            ___             ___     ___     _|_             ___
#                           |PRX|           |PRZ|   |PRX|   |CX |           |RZ |
# ----●---------------●-----|54 |-----------|55 |---|56 |---|67 |-----------|68 |-
#     |               |     |___|           |___|   |___|   |___|           |___|
#    _|_     ___     _|_     ___             ___     ___     ___
#   |CX |   |RZ |   |CX |   |RX |           |PRX|   |PRZ|   |PRX|
# --|41 |---|42 |---|43 |---|44 |-----------|57 |---|58 |---|59 |-----------------
#   |___|   |___|   |___|   |___|           |___|   |___|   |___|
#
#
# ================================================================================
#
#                                                                    ___
#                                                                   |PRX|
# ----●---------------●-------------------------------●-------------|95 |---------
#     |               |                               |             |___|
#     |               |                               |
#     |               |                               |
# ----|------●--------|------●------------------------|------●--------●-----------
#     |      |        |      |                        |      |        |
#     |     _|_       |      |      ___               |      |        |
#     |    |CX |      |      |     |RX |              |      |        |
# ----|----|76 |------|------|-----|83 |--------------|------|--------|------●----
#     |    |___|      |      |     |___|              |      |        |      |
#    _|_              |     _|_              ___      |     _|_       |     _|_
#   |CX |             |    |CX |            |RZ |     |    |CX |      |    |CX |
# --|69 |-------------|----|77 |------------|78 |-----|----|79 |------|----|84 |--
#   |___|             |    |___|            |___|     |    |___|      |    |___|
#                    _|_                     ___     _|_             _|_
#                   |CX |                   |RZ |   |CX |           |CX |
# ------------------|70 |-------------------|71 |---|72 |-----------|80 |---------
#                   |___|                   |___|   |___|           |___|
#
#
# ================================================================================
#
#    ___     ___             ___
#   |PRZ|   |PRX|           |RX |
# --|96 |---|97 |-----------|110|-----------------------------●---------------●---
#   |___|   |___|           |___|                             |               |
#                            ___             ___     ___     _|_     ___     _|_
#                           |PRX|           |PRZ|   |PRX|   |CX |   |RZ |   |CX |
# ------------●-------------|98 |-----------|99 |---|100|---|111|---|112|---|113|-
#             |             |___|           |___|   |___|   |___|   |___|   |___|
#             |                                              ___     ___     ___
#             |                                             |PRX|   |PRZ|   |PRX|
# ------------|------●--------●-----------------------●-----|101|---|102|---|103|-
#             |      |        |                       |     |___|   |___|   |___|
#    ___      |     _|_       |     ___               |
#   |RZ |     |    |CX |      |    |RX |              |
# --|85 |-----|----|86 |------|----|90 |--------------|-------●---------------●---
#   |___|     |    |___|      |    |___|              |       |               |
#    ___     _|_             _|_             ___     _|_     _|_     ___     _|_
#   |RZ |   |CX |           |CX |           |RZ |   |CX |   |CX |   |RZ |   |CX |
# --|81 |---|82 |-----------|87 |-----------|88 |---|89 |---|91 |---|92 |---|93 |-
#   |___|   |___|           |___|           |___|   |___|   |___|   |___|   |___|
#
#
# ================================================================================
#
#
#
# ----●-----------------------●-------●-----------------------●---------------●---
#     |                       |       |                       |               |
#     |     ___               |       |                       |               |
#     |    |RX |              |       |                       |               |
# ----|----|123|--------------|-------|------●----------------|------●--------|---
#     |    |___|              |       |      |                |      |        |
#    _|_             ___     _|_      |     _|_      ___      |     _|_       |
#   |CX |           |RZ |   |CX |     |    |CX |    |RZ |     |    |CX |      |
# --|114|-----------|115|---|116|-----|----|124|----|125|-----|----|126|------|---
#   |___|           |___|   |___|     |    |___|    |___|     |    |___|      |
#    ___             ___     ___     _|_             ___     _|_              |
#   |PRX|           |PRZ|   |PRX|   |CX |           |RZ |   |CX |             |
# --|104|-----------|105|---|106|---|117|-----------|118|---|119|-------------|---
#   |___|           |___|   |___|   |___|           |___|   |___|             |
#    ___             ___     ___     ___                                     _|_
#   |RX |           |PRX|   |PRZ|   |PRX|                                   |CX |
# --|94 |-----------|107|---|108|---|109|-----------------------------------|120|-
#   |___|           |___|   |___|   |___|                                   |___|
#
#
# ================================================================================
#
#                                            ___             ___     ___
#                                           |PRX|           |PRZ|   |PRX|
# ----------------------------●-------------|145|-----------|146|---|147|---------
#                             |             |___|           |___|   |___|
#                             |
#                             |
# ---●------------------------|------●--------●-----------------------●-----------
#    |                        |      |        |                       |
#    |      ___               |      |        |                       |
#    |     |RX |              |      |        |                       |
# ---|-----|133|--------------|------|--------|------●----------------|------●----
#    |     |___|              |      |        |      |                |      |
#   _|_              ___      |     _|_       |     _|_      ___      |     _|_
#  |CX |            |RZ |     |    |CX |      |    |CX |    |RZ |     |    |CX |
# -|127|------------|128|-----|----|129|------|----|134|----|135|-----|----|136|--
#  |___|            |___|     |    |___|      |    |___|    |___|     |    |___|
#                    ___     _|_             _|_             ___     _|_
#                   |RZ |   |CX |           |CX |           |RZ |   |CX |
# ------------------|121|---|122|-----------|130|-----------|131|---|132|---------
#                   |___|   |___|           |___|           |___|   |___|
#
#
# ================================================================================
#
#
#
# --------------------------------------------------------------------------------
#
#    ___             ___     ___
#   |PRX|           |PRZ|   |PRX|
# --|148|-----------|149|---|150|-------------------------------------------------
#   |___|           |___|   |___|
#                                    ___     ___     ___
#                                   |PRX|   |PRZ|   |PRX|
# ----●-----------------------●-----|151|---|152|---|153|-------------------------
#     |                       |     |___|   |___|   |___|
#     |     ___               |                              ___     ___     ___
#     |    |RX |              |                             |PRX|   |PRZ|   |PRX|
# ----|----|140|--------------|-------●---------------●-----|154|---|155|---|156|-
#     |    |___|              |       |               |     |___|   |___|   |___|
#    _|_             ___     _|_     _|_     ___     _|_     ___     ___     ___
#   |CX |           |RZ |   |CX |   |CX |   |RZ |   |CX |   |RX |   |PRX|   |PRZ|
# --|137|-----------|138|---|139|---|141|---|142|---|143|---|144|---|157|---|158|-
#   |___|           |___|   |___|   |___|   |___|   |___|   |___|   |___|   |___|
#
#
# ================================================================================
#
#
#
# --------
#
#
#
# --------
#
#
#
# --------
#
#
#
# --------
#
#    ___
#   |PRX|
# --|159|-
#   |___|
# 55

# %%
from scikit_quri.qnn.classifier import QNNClassifier
from scikit_quri.backend import SimEstimator

# optimizer = Adam()
optimizer = LBFGS()
estimator = SimEstimator()
gradient_estimator = create_numerical_gradient_estimator(
    create_qulacs_vector_concurrent_parametric_estimator(), delta=1e-10
)
qnn = QNNClassifier(circuit, num_class, estimator, gradient_estimator, optimizer=optimizer)

# %%
qnn.fit(x_train, y_train, maxiter=50)
# Out:
#  iter:49/50 cost:optimizer_state.cost=0.29538100727051835

# %%
from scipy.special import softmax
from sklearn.metrics import log_loss, confusion_matrix
import seaborn as sns

y_pred = qnn.predict(x_test)
y_pred_sm = softmax(y_pred, axis=1)

log = log_loss(y_test, y_pred_sm)
cm = confusion_matrix(y_test, y_pred.argmax(axis=1))
sns.heatmap(cm, annot=True)
print(log)
# Out:
# 0.3342007985500414
# /Users/kazumatago/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:2742: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
