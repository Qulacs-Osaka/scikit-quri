# %%
import numpy as np
from scikit_quri.circuit import LearningCircuit
from quri_parts.core.operator import Operator, pauli_label
from quri_parts.core.estimator.sampling import create_sampling_concurrent_estimator
from quri_parts.core.sampling.shots_allocator import create_proportional_shots_allocator
from quri_parts.core.measurement import bitwise_commuting_pauli_measurement

pi = np.pi

# %% [markdown]
# # Code you have to change.

# %%
# Learning Parameters
input_params = []
learning_params = [pi/4, pi/3]

operator = Operator({
    pauli_label("Z0"): 1.0,
    pauli_label("Z1"): 1.0
    })

# %%
# Create LearningCircuit instance
learning_circuit = LearningCircuit(2)
learning_circuit.add_H_gate(0)
# 軸と順序に注意。もとの例は H -> CNOT -> RX,RY で、勾配が恒等的に 0 だった:
#   (1) Bell 状態にしてから各量子ビットを回すと縮約状態が最大混合になる
#   (2) H のあとの RX は |+> を固有状態として保つので <Z0> が theta に依らない
# ここでは回転をもつれの前に置き、q0 は RY で回して <Z0> = sin(theta0) が動くようにする。
learning_circuit.add_parametric_RY_gate(0)
learning_circuit.add_parametric_RX_gate(1)
learning_circuit.add_CNOT_gate(0, 1)
# Out:
# 1

# %%
# Sampler and Estimator
from quri_parts.qulacs.sampler import create_qulacs_vector_concurrent_sampler

shots = 1024

# ローカルのシミュレータでサンプリングする。実機で回す場合は scikit-quri 側の
# ファクトリを使う（引数は device_id）。quri_parts_oqtopus.sampler の同名関数は
# device_id を取らない (executor, concurrency) なので、そちらではない。
#   from scikit_quri.backend import create_oqtopus_concurrent_sampler
#   sampler = create_oqtopus_concurrent_sampler("qulacs")
sampler = create_qulacs_vector_concurrent_sampler()

measurement_factory = bitwise_commuting_pauli_measurement
shots_allocator = create_proportional_shots_allocator()

# %% [markdown]
# # Code you don't have to change.

# %%
# Execute hadamard_grad
estimator = create_sampling_concurrent_estimator(
    total_shots=shots,
    sampler=sampler,
    measurement_factory=measurement_factory,
    shots_allocator=shots_allocator,
    )

gradients = learning_circuit.hadamard_gradient(
    np.array(input_params),
    np.array(learning_params),
    operator,
    estimator,
)

# hadamard_gradient は「学習パラメータごと」の勾配を返す（長さ =
# learning_params_count）。share_with で共有されたゲート位置は係数つきで合算済み。
print("Gradients:", gradients)
print("length:", len(gradients), "== learning_params_count:", learning_circuit.learning_params_count)

# 厳密な期待値の数値微分と突き合わせる（サンプリング誤差の範囲で一致するはず）
from quri_parts.core.state import GeneralCircuitQuantumState
from quri_parts.qulacs.estimator import create_qulacs_vector_concurrent_estimator

exact = create_qulacs_vector_concurrent_estimator()
def expectation(theta):
    bound = learning_circuit.bind_input_and_parameters(np.array(input_params), theta)
    return exact([operator], [GeneralCircuitQuantumState(learning_circuit.n_qubits, bound)])[0].value.real

h = 1e-5
theta0 = np.array(learning_params)
numerical = np.array([
    (expectation(theta0 + h * np.eye(len(theta0))[j]) - expectation(theta0 - h * np.eye(len(theta0))[j])) / (2 * h)
    for j in range(len(theta0))
])
print("numerical :", numerical)
# Out:
# Gradients: [ 0.03710938 -0.03125   ]
