# %% [markdown]
# # Libraries you have to import

# %%
import numpy as np
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
from scikit_quri.circuit import LearningCircuit
from quri_parts.circuit.utils.circuit_drawer import draw_circuit
from quri_parts.core.estimator.sampling import create_sampling_concurrent_estimator
from quri_parts.core.measurement import bitwise_commuting_pauli_measurement
from quri_parts.core.operator import Operator, pauli_label
from quri_parts.core.sampling.shots_allocator import create_proportional_shots_allocator
from quri_parts.core.state import GeneralCircuitQuantumState
from quri_parts.qulacs.sampler import create_qulacs_vector_concurrent_sampler
pi = np.pi

# %% [markdown]
# # Parameters

# %%
# Parameters for training
n_qubits = 4
n_layers = 3

shots = 1024

learning_rate = 0.1
epochs = 200

loss_threshold = 1e-3

num_data_points = 30
batch_size = min(64, num_data_points)

# %% [markdown]
# # Learning circuit

# %%
# Create Sin Learning Circuit
def create_sin_learning_circuit(n_qubits: int=4, n_layers: int=3) -> LearningCircuit:
    learning_circuit = LearningCircuit(n_qubits)
    for i in range(0, n_qubits):
        learning_circuit.add_input_RY_gate(i,input_function=lambda x: x[0])

    for i in range(n_layers):
        for j in range(n_qubits):
            learning_circuit.add_parametric_RZ_gate(j)
            learning_circuit.add_parametric_RY_gate(j)
            learning_circuit.add_parametric_RX_gate(j)
        for j in range(n_qubits):
            learning_circuit.add_CNOT_gate(j, (j + 1)%n_qubits)
            
    return learning_circuit


learning_circuit = create_sin_learning_circuit(n_qubits, n_layers)
draw_circuit(learning_circuit.circuit)
# Out:
#    ___     ___     ___     ___                             ___
#   |PRY|   |PRZ|   |PRY|   |PRX|                           |CX |
# --|0  |---|4  |---|5  |---|6  |-----●---------------------|19 |-----------------
#   |___|   |___|   |___|   |___|     |                     |___|
#    ___     ___     ___     ___     _|_             ___      |     ___
#   |PRY|   |PRZ|   |PRY|   |PRX|   |CX |           |PRZ|     |    |PRY|
# --|1  |---|7  |---|8  |---|9  |---|16 |-----●-----|23 |-----|----|24 |----------
#   |___|   |___|   |___|   |___|   |___|     |     |___|     |    |___|
#    ___     ___     ___     ___             _|_              |             ___
#   |PRY|   |PRZ|   |PRY|   |PRX|           |CX |             |            |PRZ|
# --|2  |---|10 |---|11 |---|12 |-----------|17 |-----●-------|------------|26 |--
#   |___|   |___|   |___|   |___|           |___|     |       |            |___|
#    ___     ___     ___     ___                     _|_      |
# ...

# %% [markdown]
# # Prepare variables

# %%
n_params = n_layers * n_qubits * 3

radians_list = np.linspace(0, 2 * np.pi, num_data_points)
targets = np.sin(radians_list)

params = np.random.uniform(0, 2 * np.pi, n_params)
operator = Operator({pauli_label("Z0"): 1.0})

# Sampler and Estimator
executor = ProcessPoolExecutor(n_params)
# sampler = create_oqtopus_concurrent_sampler(executor, n_params)
sampler = create_qulacs_vector_concurrent_sampler(executor, n_params)

measurement_factory = bitwise_commuting_pauli_measurement
shots_allocator = create_proportional_shots_allocator()

estimator = create_sampling_concurrent_estimator(
    total_shots=shots,
    sampler=sampler,
    measurement_factory=measurement_factory,
    shots_allocator=shots_allocator,
    )

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# ## Functions

# %%
def execute_estimator(estimator, operator, circuit, params, radians) -> float:
    bound_circuit = circuit.bind_input_and_parameters([radians], params)
    state = GeneralCircuitQuantumState(bound_circuit.qubit_count, bound_circuit)
    estimate = next(iter(estimator([operator], [state])))
    return estimate.value.real

def _one_sample_thread(estimator, operator, circuit, params, radians, target):
    expectation = execute_estimator(estimator, operator, circuit, params, radians)
    grad_exp = circuit.hadamard_gradient([radians], params, operator, estimator)
    diff = expectation - target
    loss = diff ** 2
    grad = 2 * diff * grad_exp
    return loss, grad

def compute_loss_and_gradient_parallel(
    estimator,
    operator,
    circuit,
    params,
    radians_list,
    targets,
):
    total_loss = 0.0
    total_grad = np.zeros_like(params)

    with ThreadPoolExecutor() as ex:
        futures = [
            ex.submit(
                _one_sample_thread,
                estimator,
                operator,
                circuit,
                params,
                r,
                t,
            )
            for r, t in zip(radians_list, targets)
        ]
        
        total = len(futures)
        completed = 0

        for fut in as_completed(futures):
            loss, grad = fut.result()
            total_loss += loss
            total_grad += grad
            
            completed += 1
            progress = completed / total * 100
            print(f"Progress: {completed:4}/{total:4} ({progress:6.2f}%)", flush=True)

    n = len(radians_list)
    return total_loss / n, total_grad / n

# import time
def compute_loss_and_gradient(
    estimator,
    operator,
    circuit,
    params,
    radians_list,
    targets,
):
    total_loss = 0.0
    total_grad = np.zeros_like(params)

    for radians, target in zip(radians_list, targets):
        expectation = execute_estimator(estimator, operator, circuit, params, radians)
        grad_exp = circuit.hadamard_gradient([radians], params, operator, estimator)
        diff = expectation - target
        loss = diff ** 2
        grad = 2 * diff * grad_exp

        total_loss += loss
        total_grad += grad

    n = len(radians_list)
    return total_loss / n, total_grad / n

# %% [markdown]
# ## Process

# %%
loss_history = []

for epoch in range(epochs):
    print(f"Epoch: {epoch + 1}/{epochs}")

    indices = np.random.choice(len(radians_list), batch_size, replace=False)
    batch_radians = radians_list[indices]
    batch_targets = targets[indices]

    _, grad = compute_loss_and_gradient_parallel(
        estimator,
        operator,
        learning_circuit,
        params,
        batch_radians,
        batch_targets,
    )

    params -= learning_rate * grad

    full_loss, _ = compute_loss_and_gradient_parallel(
        estimator,
        operator,
        learning_circuit,
        params,
        radians_list,
        targets,
    )

    loss_history.append(full_loss)

    print(f"Gradient: {grad}")
    print(f"Loss: {full_loss}\n")

    if full_loss < loss_threshold:
        print("Converged!")
        break


print("Training completed.")
print(f"Final loss: {loss_history[-1]:.6f}")
print(f"Learned parameters: {params}")
# Out:
# Epoch: 1/200
# Progress:    1/  30 (  3.33%)
# Progress:    2/  30 (  6.67%)
# Progress:    3/  30 ( 10.00%)
# Progress:    4/  30 ( 13.33%)
# Progress:    5/  30 ( 16.67%)
# Progress:    6/  30 ( 20.00%)
# Progress:    7/  30 ( 23.33%)
# Progress:    8/  30 ( 26.67%)
# Progress:    9/  30 ( 30.00%)
# Progress:   10/  30 ( 33.33%)
# Progress:   11/  30 ( 36.67%)
# Progress:   12/  30 ( 40.00%)
# Progress:   13/  30 ( 43.33%)
# Progress:   14/  30 ( 46.67%)
# Progress:   15/  30 ( 50.00%)
# Progress:   16/  30 ( 53.33%)
# Progress:   17/  30 ( 56.67%)
# Progress:   18/  30 ( 60.00%)
# Progress:   19/  30 ( 63.33%)
# Progress:   20/  30 ( 66.67%)
# Progress:   21/  30 ( 70.00%)
# Progress:   22/  30 ( 73.33%)
# Progress:   23/  30 ( 76.67%)
# Progress:   24/  30 ( 80.00%)
# Progress:   25/  30 ( 83.33%)
# Progress:   26/  30 ( 86.67%)
# Progress:   27/  30 ( 90.00%)
# Progress:   28/  30 ( 93.33%)
# Progress:   29/  30 ( 96.67%)
# Progress:   30/  30 (100.00%)
# ...

# %% [markdown]
# ## Visualize

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loss history

# %%
plt.figure()
plt.plot(np.arange(1, epochs + 1), loss_history)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss History")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Sin Adaptatioin

# %%
radians_plot = np.linspace(0, 2 * np.pi, 200)
true_values = np.sin(radians_plot)

predicted_values = np.array([
    execute_estimator(
        estimator,
        operator,
        learning_circuit,
        params,
        r
    )
    for r in radians_plot
])

plt.figure()
plt.plot(radians_plot, true_values, label="sin(x)")
plt.plot(radians_plot, predicted_values, label="model prediction")
plt.xlabel("radians")
plt.ylabel("value")
plt.title("Sin function vs Model prediction")
plt.legend()
plt.grid(True)
plt.show()
