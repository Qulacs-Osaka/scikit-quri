# %% [markdown]
# # Libraries you have to import

# %%
import numpy as np
from concurrent.futures import ThreadPoolExecutor
from scikit_quri.circuit import LearningCircuit
from quri_parts.circuit.utils.circuit_drawer import draw_circuit
from quri_parts.core.operator import Operator, pauli_label
from quri_parts.core.estimator.sampling import create_sampling_concurrent_estimator
from quri_parts.core.sampling.shots_allocator import create_proportional_shots_allocator
from quri_parts.core.measurement import bitwise_commuting_pauli_measurement
from quri_parts_oqtopus.sampler import create_oqtopus_concurrent_sampler

pi = np.pi

# %% [markdown]
# # Simple acquisition of gradient

# %% [markdown]
# ## Code you have to change.

# %%
# Learning Parameters
input_params = []
learning_params = [pi/4, pi/3]

operator = Operator({
    pauli_label("Z0"): 1.0,
    pauli_label("Z1"): 1.0
    })

# %%
# Create LearningCircuit instance
learning_circuit = LearningCircuit(2)
learning_circuit.add_H_gate(0)
learning_circuit.add_CNOT_gate(0, 1)
learning_circuit.add_parametric_RX_gate(0)
learning_circuit.add_parametric_RY_gate(1)

# %%
# Sampler and Estimator
shots = 1024

concurrency = len(learning_params)
executor = ThreadPoolExecutor(concurrency)
sampler = create_oqtopus_concurrent_sampler(executor, concurrency)

measurement_factory = bitwise_commuting_pauli_measurement
shots_allocator = create_proportional_shots_allocator()

# %% [markdown]
# ## Code you don't have to change.

# %%
# Execute hadamard_grad
estimator = create_sampling_concurrent_estimator(
    total_shots=shots,
    sampler=sampler,
    measurement_factory=measurement_factory,
    shots_allocator=shots_allocator,
    )

gradients = learning_circuit.hadamard_gradient(
    np.array(input_params),
    np.array(learning_params),
    operator,
    estimator,
)

print("Gradients:", gradients)

# %% [markdown]
# # Sin Learning

# %% [markdown]
# ## Parameters

# %%
# Parameters for training
n_qubits = 4
n_layers = 3

shots = 1024

learning_rate = 0.1
epochs = 500
batch_size = 20

num_data_points = 100

# %% [markdown]
# ## Learning circuit

# %%
# Create Sin Learning Circuit
def create_sin_learning_circuit(n_qubits: int=4, n_layers: int=3) -> LearningCircuit:
    learning_circuit = LearningCircuit(n_qubits)
    for i in range(0, n_qubits):
        learning_circuit.add_input_RY_gate(i,input_function=lambda x: x[0])

    for i in range(n_layers):
        for j in range(n_qubits):
            learning_circuit.add_parametric_RZ_gate(j)
            learning_circuit.add_parametric_RY_gate(j)
            learning_circuit.add_parametric_RX_gate(j)
        for j in range(n_qubits):
            learning_circuit.add_CNOT_gate(j, (j + 1)%n_qubits)
            
    return learning_circuit


learning_circuit = create_sin_learning_circuit(n_qubits, n_layers)
draw_circuit(learning_circuit.circuit)
# Out:
#    ___     ___     ___     ___                             ___
#   |PRY|   |PRZ|   |PRY|   |PRX|                           |CX |
# --|0  |---|4  |---|5  |---|6  |-----●---------------------|19 |-----------------
#   |___|   |___|   |___|   |___|     |                     |___|
#    ___     ___     ___     ___     _|_             ___      |     ___
#   |PRY|   |PRZ|   |PRY|   |PRX|   |CX |           |PRZ|     |    |PRY|
# --|1  |---|7  |---|8  |---|9  |---|16 |-----●-----|23 |-----|----|24 |----------
#   |___|   |___|   |___|   |___|   |___|     |     |___|     |    |___|
#    ___     ___     ___     ___             _|_              |             ___
#   |PRY|   |PRZ|   |PRY|   |PRX|           |CX |             |            |PRZ|
# --|2  |---|10 |---|11 |---|12 |-----------|17 |-----●-------|------------|26 |--
#   |___|   |___|   |___|   |___|           |___|     |       |            |___|
#    ___     ___     ___     ___                     _|_      |
# ...

# %% [markdown]
# ## Prepare variables

# %%
n_params = n_layers * n_qubits * 3

radians_list = np.linspace(0, 2 * np.pi, num_data_points)
targets = np.sin(radians_list)

params = np.random.uniform(0, 2 * np.pi, n_params)
operator = Operator({pauli_label("Z0"): 1.0})

# Sampler and Estimator
executor = ThreadPoolExecutor(n_params)
sampler = create_oqtopus_concurrent_sampler(executor, n_params)

measurement_factory = bitwise_commuting_pauli_measurement
shots_allocator = create_proportional_shots_allocator()

estimator = create_sampling_concurrent_estimator(
    total_shots=shots,
    sampler=sampler,
    measurement_factory=measurement_factory,
    shots_allocator=shots_allocator,
    )

# %% [markdown]
# ## Gradient Descent

# %%
def compute_loss(circuit, params, radians_list, targets):
    loss = 0.0
    for radians, target in zip(radians_list, targets):
        bound_circuit = circuit.bind_input_and_parameters(np.array([radians]), params)
        expectation = estimator([operator], bound_circuit)
        loss += (expectation - target) ** 2
    return loss / len(radians_list)

def compute_gradient(circuit, params, radians_list, targets):
    grad = np.zeros(n_params)
    for radians, target in zip(radians_list, targets):
        grad_exp = circuit.hadamard_gradient(
            np.array([radians]),
            params,
            operator,
            estimator
        )
        bound_circuit = circuit.bind_input_and_parameters(np.array([radians]), params)
        expectation = estimator([operator], bound_circuit)
        grad += 2 * (expectation - target) * grad_exp
    return grad / len(radians_list)

loss_history = []
for epoch in range(epochs):
    indices = np.random.choice(len(radians_list), batch_size, replace=False)
    batch_radians = radians_list[indices]
    batch_targets = targets[indices]

    grad = compute_gradient(learning_circuit, params, batch_radians, batch_targets)

    params -= learning_rate * grad

    loss = compute_loss(learning_circuit, params, radians_list, targets)
    loss_history.append(loss)

    if epoch % 50 == 0:
        print(f"Epoch {epoch}: Loss = {loss:.6f}")

    if loss < 1e-4:
        print("Converged!")
        break

np.save("learned_params.npy", params)

print("Training completed.")
print(f"Final loss: {loss_history[-1]:.6f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 29
#      26 batch_radians = radians_list[indices]
#      27 batch_targets = targets[indices]
# ---> 29 grad = compute_gradient(learning_circuit, params, batch_radians, batch_targets)
#      31 params -= learning_rate * grad
#      33 loss = compute_loss(learning_circuit, params, radians_list, targets)
#
# Cell In[15], line 12, in compute_gradient(circuit, params, radians_list, targets)
#      10 grad = np.zeros(n_params)
#      11 for radians, target in zip(radians_list, targets):
# ---> 12     grad_exp = circuit.hadamard_gradient(
#      13         np.array([radians]),
#      14         params,
#      15         operator,
#      16         estimator
#      17     )
#      18     bound_circuit = circuit.bind_input_and_parameters(np.array([radians]), params)
# ...
