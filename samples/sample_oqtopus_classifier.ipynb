# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split

iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
x = df.loc[:, ["petal length (cm)", "petal width (cm)"]]
x_train, x_test, y_train, y_test = train_test_split(x, iris.target, test_size=0.25, random_state=0)

x_train = x_train.to_numpy()

n_qubits = 5
num_class = 3

# %%
from scikit_quri.circuit import create_qcl_ansatz

circuit = create_qcl_ansatz(n_qubits, 3, 1.0)

# %%
from quri_parts.algo.optimizer import Adam
from quri_parts.core.estimator.gradient import (
    create_numerical_gradient_estimator,
)
from quri_parts.qulacs.estimator import (
    create_qulacs_vector_concurrent_parametric_estimator,
)

from scikit_quri.backend import OqtopusEstimator
from scikit_quri.qnn.classifier import QNNClassifier

adam = Adam()
estimator = OqtopusEstimator("qulacs")

gradient_estimator = create_numerical_gradient_estimator(
    create_qulacs_vector_concurrent_parametric_estimator(), delta=1e-10,
)
qnn = QNNClassifier(circuit, num_class, estimator, gradient_estimator, adam)

# %%
qnn.fit(x_train, y_train, maxiter=50)
# Out:
# ---------------------------------------------------------------------------
# LocationValueError                        Traceback (most recent call last)
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/backend/estimation.py:582, in OqtopusEstimationBackend.estimate_qasm(self, program, operator, device_id, shots, name, description, transpiler_info, simulator_info, mitigation_info)
#     581 try:
# --> 582     response_submit_job = self._job_api.submit_job(body=body)
#     583     response = self._job_api.get_job(response_submit_job.job_id)
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/rest/api/job_api.py:644, in JobApi.submit_job(self, **kwargs)
#     643 else:
# --> 644     (data) = self.submit_job_with_http_info(**kwargs)  # noqa: E501
#     645     return data
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/rest/api/job_api.py:704, in JobApi.submit_job_with_http_info(self, **kwargs)
#     702 auth_settings = ['BearerAuth']  # noqa: E501
# --> 704 return self.api_client.call_api(
#     705     '/jobs', 'POST',
#     706     path_params,
#     707     query_params,
#     708     header_params,
#     709     body=body_params,
#     710     post_params=form_params,
#     711     files=local_var_files,
#     712     response_type='JobsSubmitJobResponse',  # noqa: E501
#     713     auth_settings=auth_settings,
#     714     async_req=params.get('async_req'),
#     715     _return_http_data_only=params.get('_return_http_data_only'),
#     716     _preload_content=params.get('_preload_content', True),
#     717     _request_timeout=params.get('_request_timeout'),
#     718     collection_formats=collection_formats)
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/rest/api_client.py:316, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     315 if not async_req:
# --> 316     return self.__call_api(resource_path, method,
#     317                            path_params, query_params, header_params,
#     318                            body, post_params, files,
#     319                            response_type, auth_settings,
#     320                            _return_http_data_only, collection_formats,
#     321                            _preload_content, _request_timeout)
#     322 else:
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/rest/api_client.py:148, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     147 # perform request and return response
# --> 148 response_data = self.request(
#     149     method, url, query_params=query_params, headers=header_params,
#     150     post_params=post_params, body=body,
#     151     _preload_content=_preload_content,
#     152     _request_timeout=_request_timeout)
#     154 self.last_response = response_data
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/rest/api_client.py:358, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     357 elif method == "POST":
# --> 358     return self.rest_client.POST(url,
#     359                                  query_params=query_params,
#     360                                  headers=headers,
#     361                                  post_params=post_params,
#     362                                  _preload_content=_preload_content,
#     363                                  _request_timeout=_request_timeout,
#     364                                  body=body)
#     365 elif method == "PUT":
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/rest/rest.py:263, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     261 def POST(self, url, headers=None, query_params=None, post_params=None,
#     262          body=None, _preload_content=True, _request_timeout=None):
# --> 263     return self.request("POST", url,
#     264                         headers=headers,
#     265                         query_params=query_params,
#     266                         post_params=post_params,
#     267                         _preload_content=_preload_content,
#     268                         _request_timeout=_request_timeout,
#     269                         body=body)
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/rest/rest.py:161, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     160         request_body = json.dumps(body)
# --> 161     r = self.pool_manager.request(
#     162         method, url,
#     163         body=request_body,
#     164         preload_content=_preload_content,
#     165         timeout=timeout,
#     166         headers=headers)
#     167 elif headers['Content-Type'] == 'application/x-www-form-urlencoded':  # noqa: E501
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/urllib3/poolmanager.py:448, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     439     warnings.warn(
#     440         "URLs without a scheme (ie 'https://') are deprecated and will raise an error "
#     441         "in a future version of urllib3. To avoid this DeprecationWarning ensure all URLs "
#    (...)
#     445         stacklevel=2,
#     446     )
# --> 448 conn = self.connection_from_host(u.host, port=u.port, scheme=u.scheme)
#     450 kw["assert_same_host"] = False
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/urllib3/poolmanager.py:310, in PoolManager.connection_from_host(self, host, port, scheme, pool_kwargs)
#     309 if not host:
# --> 310     raise LocationValueError("No host specified.")
#     312 request_context = self._merge_pool_kwargs(pool_kwargs)
#
# LocationValueError: No host specified.
#
# The above exception was the direct cause of the following exception:
#
# BackendError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 qnn.fit(x_train, y_train, maxiter=50)
#
# File ~/Documents/GitHub/scikit-quri/scikit_quri/qnn/classifier.py:168, in QNNClassifier.fit(self, x_train, y_train, maxiter)
#     166 c = 0
#     167 while maxiter > c:
# --> 168     optimizer_state = self.optimizer.step(optimizer_state, cost_func, grad_func)
#     169     print("\r", f"iter:{c}/{maxiter} cost:{optimizer_state.cost=}", end="")
#     171     if optimizer_state.status == OptimizerStatus.CONVERGED:
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts/algo/optimizer/adam.py:126, in Adam.step(self, state, cost_function, grad_function)
#     123 niter = state.niter + 1
#     125 if niter == 1:
# --> 126     cost_prev = cost_function(state.params)
#     127     funcalls += 1
#     128 else:
#
# File ~/Documents/GitHub/scikit-quri/scikit_quri/qnn/classifier.py:162, in QNNClassifier.fit.<locals>.<lambda>(params)
#     159 # print(f"{init_params=}")
#     160 optimizer_state = self.optimizer.get_init_state(init_params)
# --> 162 cost_func = lambda params: self.cost_func(x_scaled, y_train, params)
#     163 # cost_func = partial(self.cost_func, x_scaled=x_scaled, y_train=y_train)
#     164 grad_func = lambda params: self.cost_func_grad(x_scaled, y_train, params)
#
# File ~/Documents/GitHub/scikit-quri/scikit_quri/qnn/classifier.py:246, in QNNClassifier.cost_func(self, x_scaled, y_train, params)
#     240 def cost_func(
#     241     self,
#     242     x_scaled: NDArray[np.float64],
#     243     y_train: NDArray[np.int64],
#     244     params: NDArray[np.float64],
#     245 ) -> float:
# --> 246     y_pred = self._predict_inner(x_scaled, params)
#     247     # Case of log_logg
#     248     # softmax
#     249     y_pred_sm = self._softmax(y_pred, axis=1)
#
# File ~/Documents/GitHub/scikit-quri/scikit_quri/qnn/classifier.py:234, in QNNClassifier._predict_inner(self, x_scaled, params)
#     231 for i in range(self.num_class):
#     232     # print("\r", f"pred_inner:{i}/{self.num_class}", end="")
#     233     op = self.operator[i]
# --> 234     estimates = self.estimator.estimate([op], circuit_states)
#     235     estimates = [e.value.real * self.y_exp_ratio for e in estimates]
#     236     res[:, i] = estimates.copy()
#
# File ~/Documents/GitHub/scikit-quri/scikit_quri/backend/oqtopus_estimator.py:68, in OqtopusEstimator.estimate(self, operators, states)
#      66     operators = [next(iter(operators))] * num_states
#      67 circuits = [self._transpile_circuit(state.circuit) for state in states]
# ---> 68 return self._estimate_concurrently(operators, circuits)
#
# File ~/Documents/GitHub/scikit-quri/scikit_quri/backend/oqtopus_estimator.py:89, in OqtopusEstimator._estimate_concurrently(self, operators, circuits)
#      87 if isinstance(operator, PauliLabel):
#      88     operator = Operator({operator: 1.0})
# ---> 89 job = self.backend.estimate(
#      90     circuit, operator=operator, device_id=self.device_id, shots=self.shots
#      91 )
#      92 result = job.result()
#      93 exp_real = result.exp_value
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/backend/estimation.py:483, in OqtopusEstimationBackend.estimate(self, program, operator, device_id, shots, name, description, transpiler_info, simulator_info, mitigation_info)
#     480 else:
#     481     qasm = convert_to_qasm_str(program)
# --> 483 return self.estimate_qasm(
#     484     program=qasm,
#     485     operator=operator,
#     486     device_id=device_id,
#     487     shots=shots,
#     488     name=name,
#     489     description=description,
#     490     transpiler_info=transpiler_info,
#     491     simulator_info=simulator_info,
#     492     mitigation_info=mitigation_info,
#     493 )
#
# File ~/Documents/GitHub/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/backend/estimation.py:586, in OqtopusEstimationBackend.estimate_qasm(self, program, operator, device_id, shots, name, description, transpiler_info, simulator_info, mitigation_info)
#     584 except Exception as e:
#     585     msg = "To execute estimation on OQTOPUS Cloud is failed."
# --> 586     raise BackendError(msg) from e
#     588 return OqtopusEstimationJob(response, self._job_api)
#
# BackendError: To execute estimation on OQTOPUS Cloud is failed.
