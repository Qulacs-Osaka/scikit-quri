# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split

iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
x = df.loc[:, ["petal length (cm)", "petal width (cm)"]]
x_train, x_test, y_train, y_test = train_test_split(x, iris.target, test_size=0.25, random_state=0)

x_train = x_train.to_numpy()

n_qubits = 5
num_class = 3

# %%
from scikit_quri.circuit import create_qcl_ansatz

circuit = create_qcl_ansatz(n_qubits, 3, 1.0)

# %%
from quri_parts.algo.optimizer import Adam
from quri_parts.core.estimator.gradient import (
    create_numerical_gradient_estimator,
)
from quri_parts.qulacs.estimator import (
    create_qulacs_vector_concurrent_parametric_estimator,
)

from scikit_quri.backend import OqtopusEstimator
from scikit_quri.qnn.classifier import QNNClassifier

adam = Adam()
estimator = OqtopusEstimator("qulacs")

gradient_estimator = create_numerical_gradient_estimator(
    create_qulacs_vector_concurrent_parametric_estimator(), delta=1e-10,
)
qnn = QNNClassifier(circuit, num_class, estimator, gradient_estimator, adam)

# %%
qnn.fit(x_train, y_train, maxiter=50)
# Out:
# ---------------------------------------------------------------------------
# BackendError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 qnn.fit(x_train, y_train, maxiter=50)
#
# File ~/Documents/GitHub/scikit-quri-estimator-wrapper/scikit_quri/qnn/classifier.py:171, in QNNClassifier.fit(self, x_train, y_train, maxiter)
#     169 c = 0
#     170 while maxiter > c:
# --> 171     optimizer_state = self.optimizer.step(optimizer_state, cost_func, grad_func)
#     172     print("\r", f"iter:{c}/{maxiter} cost:{optimizer_state.cost=}", end="")
#     174     if optimizer_state.status == OptimizerStatus.CONVERGED:
#
# File ~/Documents/GitHub/scikit-quri-estimator-wrapper/.venv/lib/python3.11/site-packages/quri_parts/algo/optimizer/adam.py:126, in Adam.step(self, state, cost_function, grad_function)
#     123 niter = state.niter + 1
#     125 if niter == 1:
# --> 126     cost_prev = cost_function(state.params)
#     127     funcalls += 1
#     128 else:
#
# File ~/Documents/GitHub/scikit-quri-estimator-wrapper/scikit_quri/qnn/classifier.py:162, in QNNClassifier.fit.<locals>.cost_func(params)
#     161 def cost_func(params):
# --> 162     return self.cost_func(x_scaled, y_train, params)
#
# File ~/Documents/GitHub/scikit-quri-estimator-wrapper/scikit_quri/qnn/classifier.py:249, in QNNClassifier.cost_func(self, x_scaled, y_train, params)
#     243 def cost_func(
#     244     self,
#     245     x_scaled: NDArray[np.float64],
#     246     y_train: NDArray[np.int64],
#     247     params: NDArray[np.float64],
#     248 ) -> float:
# --> 249     y_pred = self._predict_inner(x_scaled, params)
#     250     # Case of log_logg
#     251     # softmax
#     252     y_pred_sm = self._softmax(y_pred, axis=1)
#
# File ~/Documents/GitHub/scikit-quri-estimator-wrapper/scikit_quri/qnn/classifier.py:237, in QNNClassifier._predict_inner(self, x_scaled, params)
#     234 for i in range(self.num_class):
#     235     # print("\r", f"pred_inner:{i}/{self.num_class}", end="")
#     236     op = self.operator[i]
# --> 237     estimates = self.estimator.estimate([op], circuit_states)
#     238     estimates = [e.value.real * self.y_exp_ratio for e in estimates]
#     239     res[:, i] = estimates.copy()
#
# File ~/Documents/GitHub/scikit-quri-estimator-wrapper/scikit_quri/backend/oqtopus_estimator.py:79, in OqtopusEstimator.estimate(self, operators, states)
#      77     operators = [next(iter(operators))] * num_states
#      78 circuits = [self._transpile_circuit(state.circuit) for state in states]
# ---> 79 return self._estimate_concurrently(operators, circuits)
#
# File ~/Documents/GitHub/scikit-quri-estimator-wrapper/scikit_quri/backend/oqtopus_estimator.py:110, in OqtopusEstimator._estimate_concurrently(self, operators, circuits)
#     103     operator = Operator({operator: 1.0})
#     104 job = self.backend.estimate(
#     105     circuit,
#     106     operator=operator,
#     107     device_id=self.device_id,
#     108     shots=self.shots,
#     109 )
# --> 110 result = job.result()
#     111 exp_real = result.exp_value
#     112 # On failure the backend raises an exception, so exp_value is None only when the result is 0
#
# File ~/Documents/GitHub/scikit-quri-estimator-wrapper/.venv/lib/python3.11/site-packages/quri_parts_oqtopus/backend/estimation.py:347, in OqtopusEstimationJob.result(self, timeout, wait)
#     345 if self._job.status in {"failed", "cancelled"}:
#     346     msg = f"Job ended with status {self._job.status}."
# --> 347     raise BackendError(msg)
#     349 # edit json for OqtopusEstimationResult
#     350 result = self.job_info["result"]["estimation"]
#
# BackendError: Job ended with status failed.
