# %%
from scikit_quri.circuit import create_ibm_embedding_circuit
from scikit_quri.qsvm import QSVC
import numpy as np

n_qubit = 4
circuit = create_ibm_embedding_circuit(n_qubit)

# %%
bind_circ = circuit.bind_input_and_parameters(np.array([0.5]), np.array([]))
print(type(bind_circ))
(bind_circ.parameter_map)
# Out:
# <class 'quri_parts.rust.circuit.circuit_parametric.ImmutableBoundParametricQuantumCircuit'>
# {Parameter(name=): 1.8207963267948966,
#  Parameter(name=): 0.5,
#  Parameter(name=): 1.8207963267948966,
#  Parameter(name=): 0.5,
#  Parameter(name=): 1.8207963267948966,
#  Parameter(name=): 1.8207963267948966,
#  Parameter(name=): 0.5,
#  Parameter(name=): 0.5,
#  Parameter(name=): 0.5,
#  Parameter(name=): 0.5,
#  Parameter(name=): 1.8207963267948966,
#  Parameter(name=): 1.8207963267948966,
#  Parameter(name=): 1.8207963267948966,
#  Parameter(name=): 0.5,
#  Parameter(name=): 0.5,
#  Parameter(name=): 1.8207963267948966}
